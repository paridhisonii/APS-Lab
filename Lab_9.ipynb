# %% [markdown]
# <a href="https://colab.research.google.com/github/paridhisonii/APS-Lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def dijkstra(graph, start):
    distances = {node: float('inf') for node in graph}
    previous_nodes = {node: None for node in graph}
    visited = []
    distances[start] = 0
    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')
        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node
        if min_node is None:
            break
        visited.append(min_node)
        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight
            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous_nodes[neighbor] = min_node
    return distances, previous_nodes

def shortest_path(previous_nodes, start, target):
    path = []
    current = target
    while current is not None:
        path.insert(0, current)
        current = previous_nodes[current]
    if path[0] == start:
        return path
    else:
        return None

graph = {}
n = int(input("ENTER NUMBER OF NODES: "))
for i in range(n):
    node = input(f"ENTER NODE {i+1} NAME: ")
    graph[node] = {}

m = int(input("ENTER NUMBER OF EDGES: "))
for i in range(m):
    u = input("ENTER START NODE: ")
    v = input("ENTER END NODE: ")
    w = int(input("ENTER WEIGHT: "))
    graph[u][v] = w
    graph[v][u] = w

source = input("ENTER SOURCE NODE: ")
distances, previous_nodes = dijkstra(graph, source)

print("\nShortest distance from source:")
for node in graph:
    print(f"{source} → {node} = {distances[node]}")

print("\nPaths:")
for node in graph:
    if node != source:
        path = shortest_path(previous_nodes, source, node)
        print(f"{source} → {node}: {path} (distance {distances[node]})")
# Out:
# ENTER NUMBER OF NODES: 4
# ENTER NODE 1 NAME: A
# ENTER NODE 2 NAME: B
# ENTER NODE 3 NAME: C
# ENTER NODE 4 NAME: D
# ENTER NUMBER OF EDGES: 4
# ENTER START NODE: A
# ENTER END NODE: B
# ENTER WEIGHT: 1
# ENTER START NODE: B
# ENTER END NODE: C
# ENTER WEIGHT: 2
# ENTER START NODE: A
# ENTER END NODE: C
# ENTER WEIGHT: 4
# ENTER START NODE: C
# ENTER END NODE: D
# ENTER WEIGHT: 1
# ENTER SOURCE NODE: A
#
# Shortest distance from source:
# A → A = 0
# A → B = 1
# A → C = 3
# A → D = 4
#
# Paths:
# A → B: ['A', 'B'] (distance 1)
# A → C: ['A', 'B', 'C'] (distance 3)
# A → D: ['A', 'B', 'C', 'D'] (distance 4)
